# %%
marks = [78 , 85 , 62 , 87 , 74]
subjects = ["Maths" , "Physics" , "Python"]

print(marks)
print(subjects)

# %%
print(marks[0])
print(marks[-1])
print(marks[0:2])

# %%
marks[0] = 80
print("after edit :"marks)

marks.append(95)
print("afte append :" marks)

marks.remove(62)
print("after remove :" marks)

marks.sort()
print("after sort : "marks)

marks.sort(reverse=2)
print(marks)

# %%
#Tuple

location = (28.67 , 77.45)
print(location)
print("latitude : ", location[0])
print("longitude : " ,location[1])

# %%
Temp = [67 ,23, 23,56, 34]
print("Highest tremperature is :", max(Temp))
Temp.append(32)
Temp.sort()
print("temp after sort : " , Temp)
print("Average of temp : " , sum(Temp)/len(Temp))

Data = ("Negi" , 34)
print(Data)
# Out:
# Highest tremperature is : 67
# temp after sort :  [23, 23, 32, 34, 56, 67]
# Average of temp :  39.166666666666664
# ('Negi', 34)
