# %%
attendence = 89

if attendence >= 75 :
    print("Attendence is fine:)

# %%
score = 83
if score >=90:
    grade = "A"
elif score >= 75 :
    grade = "B"
elif score >= 60:
    grade = "C"
elif score >= 40:
    grade = "D"
else:
    grade = "F"

print(f"Score {score}")
# Out:
# Score 83

# %%
marks = 78
attendence = 90

if marks >= 40:
    if attendence >=75:
        print("Ellogible for exams.")
    else:
        print("Passed marks but attendence is short")
else:
    print("Not elligible")
# Out:
# Ellogible for exams.

# %%
if marks >= 40 and attendence >= 75:
    print("Ellogible for exams.")
# Out:
# Ellogible for exams.

# %%
#Q1 

num = int(input("Enter the number : "))
if num > 0:
    print("The entered number is positive")
elif num < 0:
    print("The entered number is negative")
else :
    print("The entered number is zero")


#Q2 
scholorship = int(input("Enter : "))
cgpa =  int(input("Enter : "))

if cgpa >= 8.5 and attendence >= 85:
    print("yes")
else:
    print("no")
# Out:
# The entered number is positive
# no
