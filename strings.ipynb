# %%
name = "Hello World"
print(name[0:4])
print(name[5:])
print(name[:4])
# Out:
# The kernel failed to start as the Python Environment 'Python 3.14.6' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
messy = "Jila Adhikari"
print(len(messy))
print(messy.upper())
print(messy.lower())
print(messy.title())
# Out:
# 13
# JILA ADHIKARI
# jila adhikari
# Jila Adhikari
