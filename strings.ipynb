# %%
name = "Hello World"
print(name[0:4])
print(name[5:])
print(name[:4])
# Out:
# Hell
#  World
# Hell

# %%
messy = "Jila Adhikari"
print(len(messy))
print(messy.upper())
print(messy.lower())
print(messy.title())
# Out:
# 13
# JILA ADHIKARI
# jila adhikari
# Jila Adhikari
