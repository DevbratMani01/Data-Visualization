# %%
marks_list = [78 , 85 ,58 , 76 , 92 , 39 , 85]
print("original :" , marks_list)
print("unique : " , set(marks_list))

# %%
python_students = {"Aarav" , "Diya" , "Rohan" , "Meera"}
sql_students = 

print#union
# inter
#diff

# %%
student = {
    "name" : "Aarav",
    "roll" : 42,
    "branch" : "CSE",
    "cgpa" : 8.7

}
print("name : ", student["name"])
print("cgpa :", student["cgpa"])
# Out:
# name :  Aarav
# cgpa : 8.7

# %%
s = [1,3,4,55,6 ,55 ,8 ,3]
print(s)

a = {"a" , "b" , "c"}
b = {"b" , "c" , "d"}
print(a&b)

book = {"title": "Python programming", "author": "Jhon Doe", "pages": 300}
print(book)
# Out:
# [1, 3, 4, 55, 6, 55, 8, 3]
# {'c', 'b'}
# {'title': 'Python programming', 'author': 'Jhon Doe', 'pages': 300}

# %%
students = {"Student 1" :{ "name": "Aarav","roll" : 42,"branch" : "CSE", "cgpa" : 8.7},
            "Student 2" :{ "name": "Diya","roll" : 43,"branch" : "ECE", "cgpa" : 9.1},
            "Student 3" :{ "name": "Rohan","roll" : 44,"branch" : "ME", "cgpa" : 7.5}
            }
print(students)
students["Student 1"]["name"] = "Aarav Sharma"
print(students)
# Out:
# {'Student 1': {'name': 'Aarav', 'roll': 42, 'branch': 'CSE', 'cgpa': 8.7}, 'Student 2': {'name': 'Diya', 'roll': 43, 'branch': 'ECE', 'cgpa': 9.1}, 'Student 3': {'name': 'Rohan', 'roll': 44, 'branch': 'ME', 'cgpa': 7.5}}
# {'Student 1': {'name': 'Aarav Sharma', 'roll': 42, 'branch': 'CSE', 'cgpa': 8.7}, 'Student 2': {'name': 'Diya', 'roll': 43, 'branch': 'ECE', 'cgpa': 9.1}, 'Student 3': {'name': 'Rohan', 'roll': 44, 'branch': 'ME', 'cgpa': 7.5}}

# %%
print(students)
students["Student 1"].pop("cgpa")
print(students)
# Out:
# {'Student 1': {'name': 'Aarav Sharma', 'roll': 42, 'branch': 'CSE'}, 'Student 3': {'name': 'Rohan', 'roll': 44, 'branch': 'ME', 'cgpa': 7.5}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 2
#       1 print(students)
# ----> 2 students["Student 1"].pop("cgpa")
#       3 print(students)
#
# KeyError: 'cgpa'

# %%
Books = {
    "Book 1" : {"title" : "Python Programming", "author" : "John Doe", "pages" : 300},
    "Book 2" : {"title" : "Data Science", "author" : "Jane Smith", "pages" : 250},
    "Book 3" : {"title" : "Machine Learning", "author" : "Alice Johnson", "pages" : 350}
}
print(Books["Book 1"]["title"])
print(Books["Book 2"]["author"])
print(Books["Book 3"]["pages"])
# Out:
# Python Programming
# Jane Smith
# 350
